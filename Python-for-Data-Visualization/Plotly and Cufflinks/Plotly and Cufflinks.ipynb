# %% [markdown]
# # Plotly and Cufflinks

# %% [markdown]
# Plotly is a library that allows you to create interactive plots that you can use in dashboards or websites (you can save them as html files or static images).
#
# ## Installation
#
# In order for this all to work, you'll need to install plotly and cufflinks to call plots directly off of a pandas dataframe. These libraries are not currently available through **conda** but are available through **pip**. Install the libraries at your command line/terminal using:
#
#     pip install plotly
#     pip install cufflinks
#
# ** NOTE: Make sure you only have one installation of Python on your computer when you do this, otherwise the installation may not work. **
#
# ## Imports and Set-up

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\asus\anaconda3\lib\site-packages (4.3.0)
# Requirement already satisfied: six in c:\users\asus\anaconda3\lib\site-packages (from plotly) (1.12.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\asus\anaconda3\lib\site-packages (from plotly) (1.3.3)

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__) # requires version >= 1.9.0
# Out:
# 4.1.0

# %%
import cufflinks as cf

# %%
# For Notebooks
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# For offline use
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Fake Data

# %%
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0  1.083536  1.453764  0.760810  0.778247
# 1 -0.383321 -1.695899 -0.112127  1.622336
# 2  0.588618  0.126675  0.515825  0.257907
# 3 -0.030502 -0.488575  0.751635 -0.367588
# 4  1.583073  1.822774 -2.018142  0.426409

# %%
df2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})

# %%
df2.head()
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %% [markdown]
# ## Using Cufflinks and iplot()
#
# * scatter
# * bar
# * box
# * spread
# * ratio
# * heatmap
# * surface
# * histogram
# * bubble

# %% [markdown]
# ## Scatter

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-d68919405364> in <module>
# ----> 1 df.iplot(kind='scatter',x='A',y='B',mode='markers',size=10)
#
# ~\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#    1217 		return iplot(figure,validate=validate,sharing=sharing,filename=filename,
#    1218                          online=online,asImage=asImage,asUrl=asUrl,asPlot=asPlot,
# -> 1219 			 dimensions=dimensions,display_image=kwargs.get('display_image',True))
#    1220
#    1221
#
# ~\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in iplot(figure, validate, sharing, filename, online, asImage, asUrl, asPlot, dimensions, display_image, **kwargs)
#    1459         ## iplot
#    1460         if offline.is_offline() and not online:
# -> 1461                 return offline.py_offline.iplot(figure, validate=validate, filename=filename, show_link=show_link, link_text=link_text, config=config)
#    1462         else:
#    1463 		return py.iplot(figure,validate=validate,sharing=sharing,
#
# ~\Anaconda3\lib\site-packages\plotly\offline\offline.py in iplot(figure_or_data, show_link, link_text, validate, image, filename, image_width, image_height, config, auto_play, animation_opts)
#     381
#     382     # Get figure
# --> 383     figure = tools.return_figure_from_figure_or_data(figure_or_data, validate)
#     384
#     385     # Handle image request
#
# ~\Anaconda3\lib\site-packages\plotly\tools.py in return_figure_from_figure_or_data(figure_or_data, validate_figure)
#     551
#     552         try:
# --> 553             figure = Figure(**figure).to_dict()
#     554         except exceptions.PlotlyError as err:
#     555             raise exceptions.PlotlyError(
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\_figure.py in __init__(self, data, layout, frames, skip_invalid, **kwargs)
#     586                         subset of frames.
#     587                     layout
# --> 588                         Layout properties which this frame modifies.
#     589                         The format is identical to the normal layout
#     590                         definition.
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
#     271
#     272         # Process kwargs
# --> 273         # --------------
#     274         for k, v in kwargs.items():
#     275             if k in self:
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _initialize_layout_template(self)
#    1815         plotly.tools.make_subplots
#    1816
# -> 1817         Parameters
#    1818         ----------
#    1819         row: int
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setattr__(self, prop, value)
#    4308                 "Subplot properties may only be suffixed by an "
#    4309                 "integer >= 1\n"
# -> 4310                 "Received {k}".format(k=prop)
#    4311             )
#    4312
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setattr__(self, prop, value)
#    3377
#    3378     def __contains__(self, prop):
# -> 3379         """
#    3380         Determine whether object contains a property or nested property
#    3381
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\__init__.py in template(self, val)
#    2866                  'magenta', 'magma', 'matter', 'mint', 'mrybm', 'mygbm', 'oranges',
#    2867                  'orrd', 'oryel', 'peach', 'phase', 'picnic', 'pinkyl', 'piyg',
# -> 2868                  'plasma', 'plotly3', 'portland', 'prgn', 'pubu', 'pubugn', 'puor',
#    2869                  'purd', 'purp', 'purples', 'purpor', 'rainbow', 'rdbu', 'rdgy',
#    2870                  'rdpu', 'rdylbu', 'rdylgn', 'redor', 'reds', 'solar', 'spectral',
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    4294         value
#    4295             Subplot value
# -> 4296         """
#    4297         # Get regular expression match
#    4298         # ----------------------------
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    3343         # ----------------
#    3344         if prop and prop[0] in self._mapped_properties:
# -> 3345             prop = self._mapped_properties[prop[0]] + prop[1:]
#    3346
#    3347         # Handle scalar case
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_compound_prop(self, prop, val)
#    3694         """
#    3695         Remove the value associated with the specified key and return it
# -> 3696
#    3697         Parameters
#    3698         ----------
#
# ~\Anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2701             # (could be any hashable object)
#    2702             if v in pio.templates:
# -> 2703                 return copy.deepcopy(pio.templates[v])
#    2704             # Otherwise, if v is a string, check to see if it consists of
#    2705             # multiple template names joined on '+' characters
#
# ~\Anaconda3\lib\site-packages\plotly\io\_templates.py in __getitem__(self, item)
#      75         for template_name in template_names:
#      76             template = self._templates[template_name]
# ---> 77             if template is Lazy:
#      78                 from plotly.graph_objs.layout import Template
#      79
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\layout\__init__.py in __init__(self, arg, data, layout, **kwargs)
#    9260         Returns
#    9261         -------
# -> 9262         Template
#    9263         """
#    9264         super(Template, self).__init__("template")
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    3343         # ----------------
#    3344         if prop and prop[0] in self._mapped_properties:
# -> 3345             prop = self._mapped_properties[prop[0]] + prop[1:]
#    3346
#    3347         # Handle scalar case
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_compound_prop(self, prop, val)
#    3694         """
#    3695         Remove the value associated with the specified key and return it
# -> 3696
#    3697         Parameters
#    3698         ----------
#
# ~\Anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2431
#    2432         elif isinstance(v, dict):
# -> 2433             v = self.data_class(v, skip_invalid=skip_invalid)
#    2434
#    2435         elif isinstance(v, self.data_class):
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\layout\template\__init__.py in __init__(self, arg, area, barpolar, bar, box, candlestick, carpet, choroplethmapbox, choropleth, cone, contourcarpet, contour, densitymapbox, funnelarea, funnel, heatmapgl, heatmap, histogram2dcontour, histogram2d, histogram, indicator, isosurface, mesh3d, ohlc, parcats, parcoords, pie, pointcloud, sankey, scatter3d, scattercarpet, scattergeo, scattergl, scattermapbox, scatterpolargl, scatterpolar, scatter, scatterternary, splom, streamtube, sunburst, surface, table, violin, volume, waterfall, **kwargs)
#    1475
#    1476         # Initialize validators
# -> 1477         # ---------------------
#    1478         self._validators["area"] = v_data.AreasValidator()
#    1479         self._validators["barpolar"] = v_data.BarpolarsValidator()
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    3347         # Handle scalar case
#    3348         # ------------------
# -> 3349         # e.g. ('foo',)
#    3350         if len(prop) == 1:
#    3351             # Unwrap scalar tuple
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_array_prop(self, prop, val)
#    3769         # -----------
#    3770         if val is None:
# -> 3771             # Check if we should send null update
#    3772             if self._props and prop in self._props:
#    3773                 # Remove property if not in batch mode
#
# ~\Anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2519                     res.append(self.data_class(v_el))
#    2520                 elif isinstance(v_el, dict):
# -> 2521                     res.append(self.data_class(v_el, skip_invalid=skip_invalid))
#    2522                 else:
#    2523                     if skip_invalid:
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\__init__.py in __init__(self, arg, a, a0, aaxis, asrc, b, b0, baxis, bsrc, carpet, cheaterslope, color, customdata, customdatasrc, da, db, font, hoverinfo, hoverinfosrc, hoverlabel, ids, idssrc, meta, metasrc, name, opacity, stream, uid, uirevision, visible, x, xaxis, xsrc, y, yaxis, ysrc, **kwargs)
#   83412                 bordercolor
#   83413                     Sets the border color of the hover labels for
# > 83414                     this trace.
#   83415                 bordercolorsrc
#   83416                     Sets the source reference on plot.ly for
#
# AttributeError: module 'plotly.validators.carpet' has no attribute 'HoverinfoValidator'

# %% [markdown]
# ## Bar Plots

# %%
df2.iplot(kind='bar',x='Category',y='Values')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-2f0d9551f1ed> in <module>
# ----> 1 df2.iplot(kind='bar',x='Category',y='Values')
#
# ~\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#    1217 		return iplot(figure,validate=validate,sharing=sharing,filename=filename,
#    1218                          online=online,asImage=asImage,asUrl=asUrl,asPlot=asPlot,
# -> 1219 			 dimensions=dimensions,display_image=kwargs.get('display_image',True))
#    1220
#    1221
#
# ~\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in iplot(figure, validate, sharing, filename, online, asImage, asUrl, asPlot, dimensions, display_image, **kwargs)
#    1459         ## iplot
#    1460         if offline.is_offline() and not online:
# -> 1461                 return offline.py_offline.iplot(figure, validate=validate, filename=filename, show_link=show_link, link_text=link_text, config=config)
#    1462         else:
#    1463 		return py.iplot(figure,validate=validate,sharing=sharing,
#
# ~\Anaconda3\lib\site-packages\plotly\offline\offline.py in iplot(figure_or_data, show_link, link_text, validate, image, filename, image_width, image_height, config, auto_play, animation_opts)
#     381
#     382     # Get figure
# --> 383     figure = tools.return_figure_from_figure_or_data(figure_or_data, validate)
#     384
#     385     # Handle image request
#
# ~\Anaconda3\lib\site-packages\plotly\tools.py in return_figure_from_figure_or_data(figure_or_data, validate_figure)
#     551
#     552         try:
# --> 553             figure = Figure(**figure).to_dict()
#     554         except exceptions.PlotlyError as err:
#     555             raise exceptions.PlotlyError(
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\_figure.py in __init__(self, data, layout, frames, skip_invalid, **kwargs)
#     586                         subset of frames.
#     587                     layout
# --> 588                         Layout properties which this frame modifies.
#     589                         The format is identical to the normal layout
#     590                         definition.
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
#     271
#     272         # Process kwargs
# --> 273         # --------------
#     274         for k, v in kwargs.items():
#     275             if k in self:
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _initialize_layout_template(self)
#    1815         plotly.tools.make_subplots
#    1816
# -> 1817         Parameters
#    1818         ----------
#    1819         row: int
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setattr__(self, prop, value)
#    4308                 "Subplot properties may only be suffixed by an "
#    4309                 "integer >= 1\n"
# -> 4310                 "Received {k}".format(k=prop)
#    4311             )
#    4312
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setattr__(self, prop, value)
#    3377
#    3378     def __contains__(self, prop):
# -> 3379         """
#    3380         Determine whether object contains a property or nested property
#    3381
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\__init__.py in template(self, val)
#    2866                  'magenta', 'magma', 'matter', 'mint', 'mrybm', 'mygbm', 'oranges',
#    2867                  'orrd', 'oryel', 'peach', 'phase', 'picnic', 'pinkyl', 'piyg',
# -> 2868                  'plasma', 'plotly3', 'portland', 'prgn', 'pubu', 'pubugn', 'puor',
#    2869                  'purd', 'purp', 'purples', 'purpor', 'rainbow', 'rdbu', 'rdgy',
#    2870                  'rdpu', 'rdylbu', 'rdylgn', 'redor', 'reds', 'solar', 'spectral',
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    4294         value
#    4295             Subplot value
# -> 4296         """
#    4297         # Get regular expression match
#    4298         # ----------------------------
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    3343         # ----------------
#    3344         if prop and prop[0] in self._mapped_properties:
# -> 3345             prop = self._mapped_properties[prop[0]] + prop[1:]
#    3346
#    3347         # Handle scalar case
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_compound_prop(self, prop, val)
#    3694         """
#    3695         Remove the value associated with the specified key and return it
# -> 3696
#    3697         Parameters
#    3698         ----------
#
# ~\Anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2701             # (could be any hashable object)
#    2702             if v in pio.templates:
# -> 2703                 return copy.deepcopy(pio.templates[v])
#    2704             # Otherwise, if v is a string, check to see if it consists of
#    2705             # multiple template names joined on '+' characters
#
# ~\Anaconda3\lib\site-packages\plotly\io\_templates.py in __getitem__(self, item)
#      75         for template_name in template_names:
#      76             template = self._templates[template_name]
# ---> 77             if template is Lazy:
#      78                 from plotly.graph_objs.layout import Template
#      79
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\layout\__init__.py in __init__(self, arg, data, layout, **kwargs)
#    9260         Returns
#    9261         -------
# -> 9262         Template
#    9263         """
#    9264         super(Template, self).__init__("template")
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    3343         # ----------------
#    3344         if prop and prop[0] in self._mapped_properties:
# -> 3345             prop = self._mapped_properties[prop[0]] + prop[1:]
#    3346
#    3347         # Handle scalar case
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_compound_prop(self, prop, val)
#    3694         """
#    3695         Remove the value associated with the specified key and return it
# -> 3696
#    3697         Parameters
#    3698         ----------
#
# ~\Anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2431
#    2432         elif isinstance(v, dict):
# -> 2433             v = self.data_class(v, skip_invalid=skip_invalid)
#    2434
#    2435         elif isinstance(v, self.data_class):
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\layout\template\__init__.py in __init__(self, arg, area, barpolar, bar, box, candlestick, carpet, choroplethmapbox, choropleth, cone, contourcarpet, contour, densitymapbox, funnelarea, funnel, heatmapgl, heatmap, histogram2dcontour, histogram2d, histogram, indicator, isosurface, mesh3d, ohlc, parcats, parcoords, pie, pointcloud, sankey, scatter3d, scattercarpet, scattergeo, scattergl, scattermapbox, scatterpolargl, scatterpolar, scatter, scatterternary, splom, streamtube, sunburst, surface, table, violin, volume, waterfall, **kwargs)
#    1475
#    1476         # Initialize validators
# -> 1477         # ---------------------
#    1478         self._validators["area"] = v_data.AreasValidator()
#    1479         self._validators["barpolar"] = v_data.BarpolarsValidator()
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    3347         # Handle scalar case
#    3348         # ------------------
# -> 3349         # e.g. ('foo',)
#    3350         if len(prop) == 1:
#    3351             # Unwrap scalar tuple
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_array_prop(self, prop, val)
#    3769         # -----------
#    3770         if val is None:
# -> 3771             # Check if we should send null update
#    3772             if self._props and prop in self._props:
#    3773                 # Remove property if not in batch mode
#
# ~\Anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2519                     res.append(self.data_class(v_el))
#    2520                 elif isinstance(v_el, dict):
# -> 2521                     res.append(self.data_class(v_el, skip_invalid=skip_invalid))
#    2522                 else:
#    2523                     if skip_invalid:
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\__init__.py in __init__(self, arg, a, a0, aaxis, asrc, b, b0, baxis, bsrc, carpet, cheaterslope, color, customdata, customdatasrc, da, db, font, hoverinfo, hoverinfosrc, hoverlabel, ids, idssrc, meta, metasrc, name, opacity, stream, uid, uirevision, visible, x, xaxis, xsrc, y, yaxis, ysrc, **kwargs)
#   83412                 bordercolor
#   83413                     Sets the border color of the hover labels for
# > 83414                     this trace.
#   83415                 bordercolorsrc
#   83416                     Sets the source reference on plot.ly for
#
# AttributeError: module 'plotly.validators.carpet' has no attribute 'HoverinfoValidator'

# %%
df.count().iplot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-8be0c316ac67> in <module>
# ----> 1 df.count().iplot(kind='bar')
#
# ~\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#    1217 		return iplot(figure,validate=validate,sharing=sharing,filename=filename,
#    1218                          online=online,asImage=asImage,asUrl=asUrl,asPlot=asPlot,
# -> 1219 			 dimensions=dimensions,display_image=kwargs.get('display_image',True))
#    1220
#    1221
#
# ~\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in iplot(figure, validate, sharing, filename, online, asImage, asUrl, asPlot, dimensions, display_image, **kwargs)
#    1459         ## iplot
#    1460         if offline.is_offline() and not online:
# -> 1461                 return offline.py_offline.iplot(figure, validate=validate, filename=filename, show_link=show_link, link_text=link_text, config=config)
#    1462         else:
#    1463 		return py.iplot(figure,validate=validate,sharing=sharing,
#
# ~\Anaconda3\lib\site-packages\plotly\offline\offline.py in iplot(figure_or_data, show_link, link_text, validate, image, filename, image_width, image_height, config, auto_play, animation_opts)
#     381
#     382     # Get figure
# --> 383     figure = tools.return_figure_from_figure_or_data(figure_or_data, validate)
#     384
#     385     # Handle image request
#
# ~\Anaconda3\lib\site-packages\plotly\tools.py in return_figure_from_figure_or_data(figure_or_data, validate_figure)
#     551
#     552         try:
# --> 553             figure = Figure(**figure).to_dict()
#     554         except exceptions.PlotlyError as err:
#     555             raise exceptions.PlotlyError(
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\_figure.py in __init__(self, data, layout, frames, skip_invalid, **kwargs)
#     586                         subset of frames.
#     587                     layout
# --> 588                         Layout properties which this frame modifies.
#     589                         The format is identical to the normal layout
#     590                         definition.
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
#     271
#     272         # Process kwargs
# --> 273         # --------------
#     274         for k, v in kwargs.items():
#     275             if k in self:
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _initialize_layout_template(self)
#    1815         plotly.tools.make_subplots
#    1816
# -> 1817         Parameters
#    1818         ----------
#    1819         row: int
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setattr__(self, prop, value)
#    4308                 "Subplot properties may only be suffixed by an "
#    4309                 "integer >= 1\n"
# -> 4310                 "Received {k}".format(k=prop)
#    4311             )
#    4312
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setattr__(self, prop, value)
#    3377
#    3378     def __contains__(self, prop):
# -> 3379         """
#    3380         Determine whether object contains a property or nested property
#    3381
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\__init__.py in template(self, val)
#    2866                  'magenta', 'magma', 'matter', 'mint', 'mrybm', 'mygbm', 'oranges',
#    2867                  'orrd', 'oryel', 'peach', 'phase', 'picnic', 'pinkyl', 'piyg',
# -> 2868                  'plasma', 'plotly3', 'portland', 'prgn', 'pubu', 'pubugn', 'puor',
#    2869                  'purd', 'purp', 'purples', 'purpor', 'rainbow', 'rdbu', 'rdgy',
#    2870                  'rdpu', 'rdylbu', 'rdylgn', 'redor', 'reds', 'solar', 'spectral',
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    4294         value
#    4295             Subplot value
# -> 4296         """
#    4297         # Get regular expression match
#    4298         # ----------------------------
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    3343         # ----------------
#    3344         if prop and prop[0] in self._mapped_properties:
# -> 3345             prop = self._mapped_properties[prop[0]] + prop[1:]
#    3346
#    3347         # Handle scalar case
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_compound_prop(self, prop, val)
#    3694         """
#    3695         Remove the value associated with the specified key and return it
# -> 3696
#    3697         Parameters
#    3698         ----------
#
# ~\Anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2701             # (could be any hashable object)
#    2702             if v in pio.templates:
# -> 2703                 return copy.deepcopy(pio.templates[v])
#    2704             # Otherwise, if v is a string, check to see if it consists of
#    2705             # multiple template names joined on '+' characters
#
# ~\Anaconda3\lib\site-packages\plotly\io\_templates.py in __getitem__(self, item)
#      75         for template_name in template_names:
#      76             template = self._templates[template_name]
# ---> 77             if template is Lazy:
#      78                 from plotly.graph_objs.layout import Template
#      79
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\layout\__init__.py in __init__(self, arg, data, layout, **kwargs)
#    9260         Returns
#    9261         -------
# -> 9262         Template
#    9263         """
#    9264         super(Template, self).__init__("template")
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    3343         # ----------------
#    3344         if prop and prop[0] in self._mapped_properties:
# -> 3345             prop = self._mapped_properties[prop[0]] + prop[1:]
#    3346
#    3347         # Handle scalar case
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_compound_prop(self, prop, val)
#    3694         """
#    3695         Remove the value associated with the specified key and return it
# -> 3696
#    3697         Parameters
#    3698         ----------
#
# ~\Anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2431
#    2432         elif isinstance(v, dict):
# -> 2433             v = self.data_class(v, skip_invalid=skip_invalid)
#    2434
#    2435         elif isinstance(v, self.data_class):
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\layout\template\__init__.py in __init__(self, arg, area, barpolar, bar, box, candlestick, carpet, choroplethmapbox, choropleth, cone, contourcarpet, contour, densitymapbox, funnelarea, funnel, heatmapgl, heatmap, histogram2dcontour, histogram2d, histogram, indicator, isosurface, mesh3d, ohlc, parcats, parcoords, pie, pointcloud, sankey, scatter3d, scattercarpet, scattergeo, scattergl, scattermapbox, scatterpolargl, scatterpolar, scatter, scatterternary, splom, streamtube, sunburst, surface, table, violin, volume, waterfall, **kwargs)
#    1475
#    1476         # Initialize validators
# -> 1477         # ---------------------
#    1478         self._validators["area"] = v_data.AreasValidator()
#    1479         self._validators["barpolar"] = v_data.BarpolarsValidator()
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    3347         # Handle scalar case
#    3348         # ------------------
# -> 3349         # e.g. ('foo',)
#    3350         if len(prop) == 1:
#    3351             # Unwrap scalar tuple
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_array_prop(self, prop, val)
#    3769         # -----------
#    3770         if val is None:
# -> 3771             # Check if we should send null update
#    3772             if self._props and prop in self._props:
#    3773                 # Remove property if not in batch mode
#
# ~\Anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2519                     res.append(self.data_class(v_el))
#    2520                 elif isinstance(v_el, dict):
# -> 2521                     res.append(self.data_class(v_el, skip_invalid=skip_invalid))
#    2522                 else:
#    2523                     if skip_invalid:
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\__init__.py in __init__(self, arg, a, a0, aaxis, asrc, b, b0, baxis, bsrc, carpet, cheaterslope, color, customdata, customdatasrc, da, db, font, hoverinfo, hoverinfosrc, hoverlabel, ids, idssrc, meta, metasrc, name, opacity, stream, uid, uirevision, visible, x, xaxis, xsrc, y, yaxis, ysrc, **kwargs)
#   83412                 bordercolor
#   83413                     Sets the border color of the hover labels for
# > 83414                     this trace.
#   83415                 bordercolorsrc
#   83416                     Sets the source reference on plot.ly for
#
# AttributeError: module 'plotly.validators.carpet' has no attribute 'HoverinfoValidator'

# %% [markdown]
# ## Boxplots

# %%
df.iplot(kind='box')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-ecfafd929c5a> in <module>
# ----> 1 df.iplot(kind='box')
#
# ~\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#    1217 		return iplot(figure,validate=validate,sharing=sharing,filename=filename,
#    1218                          online=online,asImage=asImage,asUrl=asUrl,asPlot=asPlot,
# -> 1219 			 dimensions=dimensions,display_image=kwargs.get('display_image',True))
#    1220
#    1221
#
# ~\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in iplot(figure, validate, sharing, filename, online, asImage, asUrl, asPlot, dimensions, display_image, **kwargs)
#    1459         ## iplot
#    1460         if offline.is_offline() and not online:
# -> 1461                 return offline.py_offline.iplot(figure, validate=validate, filename=filename, show_link=show_link, link_text=link_text, config=config)
#    1462         else:
#    1463 		return py.iplot(figure,validate=validate,sharing=sharing,
#
# ~\Anaconda3\lib\site-packages\plotly\offline\offline.py in iplot(figure_or_data, show_link, link_text, validate, image, filename, image_width, image_height, config, auto_play, animation_opts)
#     381
#     382     # Get figure
# --> 383     figure = tools.return_figure_from_figure_or_data(figure_or_data, validate)
#     384
#     385     # Handle image request
#
# ~\Anaconda3\lib\site-packages\plotly\tools.py in return_figure_from_figure_or_data(figure_or_data, validate_figure)
#     551
#     552         try:
# --> 553             figure = Figure(**figure).to_dict()
#     554         except exceptions.PlotlyError as err:
#     555             raise exceptions.PlotlyError(
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\_figure.py in __init__(self, data, layout, frames, skip_invalid, **kwargs)
#     586                         subset of frames.
#     587                     layout
# --> 588                         Layout properties which this frame modifies.
#     589                         The format is identical to the normal layout
#     590                         definition.
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
#     271
#     272         # Process kwargs
# --> 273         # --------------
#     274         for k, v in kwargs.items():
#     275             if k in self:
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _initialize_layout_template(self)
#    1815         plotly.tools.make_subplots
#    1816
# -> 1817         Parameters
#    1818         ----------
#    1819         row: int
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setattr__(self, prop, value)
#    4308                 "Subplot properties may only be suffixed by an "
#    4309                 "integer >= 1\n"
# -> 4310                 "Received {k}".format(k=prop)
#    4311             )
#    4312
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setattr__(self, prop, value)
#    3377
#    3378     def __contains__(self, prop):
# -> 3379         """
#    3380         Determine whether object contains a property or nested property
#    3381
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\__init__.py in template(self, val)
#    2866                  'magenta', 'magma', 'matter', 'mint', 'mrybm', 'mygbm', 'oranges',
#    2867                  'orrd', 'oryel', 'peach', 'phase', 'picnic', 'pinkyl', 'piyg',
# -> 2868                  'plasma', 'plotly3', 'portland', 'prgn', 'pubu', 'pubugn', 'puor',
#    2869                  'purd', 'purp', 'purples', 'purpor', 'rainbow', 'rdbu', 'rdgy',
#    2870                  'rdpu', 'rdylbu', 'rdylgn', 'redor', 'reds', 'solar', 'spectral',
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    4294         value
#    4295             Subplot value
# -> 4296         """
#    4297         # Get regular expression match
#    4298         # ----------------------------
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    3343         # ----------------
#    3344         if prop and prop[0] in self._mapped_properties:
# -> 3345             prop = self._mapped_properties[prop[0]] + prop[1:]
#    3346
#    3347         # Handle scalar case
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_compound_prop(self, prop, val)
#    3694         """
#    3695         Remove the value associated with the specified key and return it
# -> 3696
#    3697         Parameters
#    3698         ----------
#
# ~\Anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2701             # (could be any hashable object)
#    2702             if v in pio.templates:
# -> 2703                 return copy.deepcopy(pio.templates[v])
#    2704             # Otherwise, if v is a string, check to see if it consists of
#    2705             # multiple template names joined on '+' characters
#
# ~\Anaconda3\lib\site-packages\plotly\io\_templates.py in __getitem__(self, item)
#      75         for template_name in template_names:
#      76             template = self._templates[template_name]
# ---> 77             if template is Lazy:
#      78                 from plotly.graph_objs.layout import Template
#      79
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\layout\__init__.py in __init__(self, arg, data, layout, **kwargs)
#    9260         Returns
#    9261         -------
# -> 9262         Template
#    9263         """
#    9264         super(Template, self).__init__("template")
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    3343         # ----------------
#    3344         if prop and prop[0] in self._mapped_properties:
# -> 3345             prop = self._mapped_properties[prop[0]] + prop[1:]
#    3346
#    3347         # Handle scalar case
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_compound_prop(self, prop, val)
#    3694         """
#    3695         Remove the value associated with the specified key and return it
# -> 3696
#    3697         Parameters
#    3698         ----------
#
# ~\Anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2431
#    2432         elif isinstance(v, dict):
# -> 2433             v = self.data_class(v, skip_invalid=skip_invalid)
#    2434
#    2435         elif isinstance(v, self.data_class):
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\layout\template\__init__.py in __init__(self, arg, area, barpolar, bar, box, candlestick, carpet, choroplethmapbox, choropleth, cone, contourcarpet, contour, densitymapbox, funnelarea, funnel, heatmapgl, heatmap, histogram2dcontour, histogram2d, histogram, indicator, isosurface, mesh3d, ohlc, parcats, parcoords, pie, pointcloud, sankey, scatter3d, scattercarpet, scattergeo, scattergl, scattermapbox, scatterpolargl, scatterpolar, scatter, scatterternary, splom, streamtube, sunburst, surface, table, violin, volume, waterfall, **kwargs)
#    1475
#    1476         # Initialize validators
# -> 1477         # ---------------------
#    1478         self._validators["area"] = v_data.AreasValidator()
#    1479         self._validators["barpolar"] = v_data.BarpolarsValidator()
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    3347         # Handle scalar case
#    3348         # ------------------
# -> 3349         # e.g. ('foo',)
#    3350         if len(prop) == 1:
#    3351             # Unwrap scalar tuple
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_array_prop(self, prop, val)
#    3769         # -----------
#    3770         if val is None:
# -> 3771             # Check if we should send null update
#    3772             if self._props and prop in self._props:
#    3773                 # Remove property if not in batch mode
#
# ~\Anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2519                     res.append(self.data_class(v_el))
#    2520                 elif isinstance(v_el, dict):
# -> 2521                     res.append(self.data_class(v_el, skip_invalid=skip_invalid))
#    2522                 else:
#    2523                     if skip_invalid:
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\__init__.py in __init__(self, arg, a, a0, aaxis, asrc, b, b0, baxis, bsrc, carpet, cheaterslope, color, customdata, customdatasrc, da, db, font, hoverinfo, hoverinfosrc, hoverlabel, ids, idssrc, meta, metasrc, name, opacity, stream, uid, uirevision, visible, x, xaxis, xsrc, y, yaxis, ysrc, **kwargs)
#   83412                 bordercolor
#   83413                     Sets the border color of the hover labels for
# > 83414                     this trace.
#   83415                 bordercolorsrc
#   83416                     Sets the source reference on plot.ly for
#
# AttributeError: module 'plotly.validators.carpet' has no attribute 'HoverinfoValidator'

# %% [markdown]
# ## 3d Surface

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-ee30c24fab53> in <module>
#       1 df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})
# ----> 2 df3.iplot(kind='surface',colorscale='rdylbu')
#
# ~\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#    1217 		return iplot(figure,validate=validate,sharing=sharing,filename=filename,
#    1218                          online=online,asImage=asImage,asUrl=asUrl,asPlot=asPlot,
# -> 1219 			 dimensions=dimensions,display_image=kwargs.get('display_image',True))
#    1220
#    1221
#
# ~\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in iplot(figure, validate, sharing, filename, online, asImage, asUrl, asPlot, dimensions, display_image, **kwargs)
#    1459         ## iplot
#    1460         if offline.is_offline() and not online:
# -> 1461                 return offline.py_offline.iplot(figure, validate=validate, filename=filename, show_link=show_link, link_text=link_text, config=config)
#    1462         else:
#    1463 		return py.iplot(figure,validate=validate,sharing=sharing,
#
# ~\Anaconda3\lib\site-packages\plotly\offline\offline.py in iplot(figure_or_data, show_link, link_text, validate, image, filename, image_width, image_height, config, auto_play, animation_opts)
#     381
#     382     # Get figure
# --> 383     figure = tools.return_figure_from_figure_or_data(figure_or_data, validate)
#     384
#     385     # Handle image request
#
# ~\Anaconda3\lib\site-packages\plotly\tools.py in return_figure_from_figure_or_data(figure_or_data, validate_figure)
#     551
#     552         try:
# --> 553             figure = Figure(**figure).to_dict()
#     554         except exceptions.PlotlyError as err:
#     555             raise exceptions.PlotlyError(
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\_figure.py in __init__(self, data, layout, frames, skip_invalid, **kwargs)
#     586                         subset of frames.
#     587                     layout
# --> 588                         Layout properties which this frame modifies.
#     589                         The format is identical to the normal layout
#     590                         definition.
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
#     271
#     272         # Process kwargs
# --> 273         # --------------
#     274         for k, v in kwargs.items():
#     275             if k in self:
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _initialize_layout_template(self)
#    1815         plotly.tools.make_subplots
#    1816
# -> 1817         Parameters
#    1818         ----------
#    1819         row: int
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setattr__(self, prop, value)
#    4308                 "Subplot properties may only be suffixed by an "
#    4309                 "integer >= 1\n"
# -> 4310                 "Received {k}".format(k=prop)
#    4311             )
#    4312
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setattr__(self, prop, value)
#    3377
#    3378     def __contains__(self, prop):
# -> 3379         """
#    3380         Determine whether object contains a property or nested property
#    3381
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\__init__.py in template(self, val)
#    2866                  'magenta', 'magma', 'matter', 'mint', 'mrybm', 'mygbm', 'oranges',
#    2867                  'orrd', 'oryel', 'peach', 'phase', 'picnic', 'pinkyl', 'piyg',
# -> 2868                  'plasma', 'plotly3', 'portland', 'prgn', 'pubu', 'pubugn', 'puor',
#    2869                  'purd', 'purp', 'purples', 'purpor', 'rainbow', 'rdbu', 'rdgy',
#    2870                  'rdpu', 'rdylbu', 'rdylgn', 'redor', 'reds', 'solar', 'spectral',
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    4294         value
#    4295             Subplot value
# -> 4296         """
#    4297         # Get regular expression match
#    4298         # ----------------------------
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    3343         # ----------------
#    3344         if prop and prop[0] in self._mapped_properties:
# -> 3345             prop = self._mapped_properties[prop[0]] + prop[1:]
#    3346
#    3347         # Handle scalar case
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_compound_prop(self, prop, val)
#    3694         """
#    3695         Remove the value associated with the specified key and return it
# -> 3696
#    3697         Parameters
#    3698         ----------
#
# ~\Anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2701             # (could be any hashable object)
#    2702             if v in pio.templates:
# -> 2703                 return copy.deepcopy(pio.templates[v])
#    2704             # Otherwise, if v is a string, check to see if it consists of
#    2705             # multiple template names joined on '+' characters
#
# ~\Anaconda3\lib\site-packages\plotly\io\_templates.py in __getitem__(self, item)
#      75         for template_name in template_names:
#      76             template = self._templates[template_name]
# ---> 77             if template is Lazy:
#      78                 from plotly.graph_objs.layout import Template
#      79
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\layout\__init__.py in __init__(self, arg, data, layout, **kwargs)
#    9260         Returns
#    9261         -------
# -> 9262         Template
#    9263         """
#    9264         super(Template, self).__init__("template")
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    3343         # ----------------
#    3344         if prop and prop[0] in self._mapped_properties:
# -> 3345             prop = self._mapped_properties[prop[0]] + prop[1:]
#    3346
#    3347         # Handle scalar case
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_compound_prop(self, prop, val)
#    3694         """
#    3695         Remove the value associated with the specified key and return it
# -> 3696
#    3697         Parameters
#    3698         ----------
#
# ~\Anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2431
#    2432         elif isinstance(v, dict):
# -> 2433             v = self.data_class(v, skip_invalid=skip_invalid)
#    2434
#    2435         elif isinstance(v, self.data_class):
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\layout\template\__init__.py in __init__(self, arg, area, barpolar, bar, box, candlestick, carpet, choroplethmapbox, choropleth, cone, contourcarpet, contour, densitymapbox, funnelarea, funnel, heatmapgl, heatmap, histogram2dcontour, histogram2d, histogram, indicator, isosurface, mesh3d, ohlc, parcats, parcoords, pie, pointcloud, sankey, scatter3d, scattercarpet, scattergeo, scattergl, scattermapbox, scatterpolargl, scatterpolar, scatter, scatterternary, splom, streamtube, sunburst, surface, table, violin, volume, waterfall, **kwargs)
#    1475
#    1476         # Initialize validators
# -> 1477         # ---------------------
#    1478         self._validators["area"] = v_data.AreasValidator()
#    1479         self._validators["barpolar"] = v_data.BarpolarsValidator()
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    3347         # Handle scalar case
#    3348         # ------------------
# -> 3349         # e.g. ('foo',)
#    3350         if len(prop) == 1:
#    3351             # Unwrap scalar tuple
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_array_prop(self, prop, val)
#    3769         # -----------
#    3770         if val is None:
# -> 3771             # Check if we should send null update
#    3772             if self._props and prop in self._props:
#    3773                 # Remove property if not in batch mode
#
# ~\Anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2519                     res.append(self.data_class(v_el))
#    2520                 elif isinstance(v_el, dict):
# -> 2521                     res.append(self.data_class(v_el, skip_invalid=skip_invalid))
#    2522                 else:
#    2523                     if skip_invalid:
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\__init__.py in __init__(self, arg, a, a0, aaxis, asrc, b, b0, baxis, bsrc, carpet, cheaterslope, color, customdata, customdatasrc, da, db, font, hoverinfo, hoverinfosrc, hoverlabel, ids, idssrc, meta, metasrc, name, opacity, stream, uid, uirevision, visible, x, xaxis, xsrc, y, yaxis, ysrc, **kwargs)
#   83412                 bordercolor
#   83413                     Sets the border color of the hover labels for
# > 83414                     this trace.
#   83415                 bordercolorsrc
#   83416                     Sets the source reference on plot.ly for
#
# AttributeError: module 'plotly.validators.carpet' has no attribute 'HoverinfoValidator'

# %% [markdown]
# ## Spread

# %%
df[['A','B']].iplot(kind='spread')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-18829c1a8e63> in <module>
# ----> 1 df[['A','B']].iplot(kind='spread')
#
# ~\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#    1217 		return iplot(figure,validate=validate,sharing=sharing,filename=filename,
#    1218                          online=online,asImage=asImage,asUrl=asUrl,asPlot=asPlot,
# -> 1219 			 dimensions=dimensions,display_image=kwargs.get('display_image',True))
#    1220
#    1221
#
# ~\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in iplot(figure, validate, sharing, filename, online, asImage, asUrl, asPlot, dimensions, display_image, **kwargs)
#    1459         ## iplot
#    1460         if offline.is_offline() and not online:
# -> 1461                 return offline.py_offline.iplot(figure, validate=validate, filename=filename, show_link=show_link, link_text=link_text, config=config)
#    1462         else:
#    1463 		return py.iplot(figure,validate=validate,sharing=sharing,
#
# ~\Anaconda3\lib\site-packages\plotly\offline\offline.py in iplot(figure_or_data, show_link, link_text, validate, image, filename, image_width, image_height, config, auto_play, animation_opts)
#     381
#     382     # Get figure
# --> 383     figure = tools.return_figure_from_figure_or_data(figure_or_data, validate)
#     384
#     385     # Handle image request
#
# ~\Anaconda3\lib\site-packages\plotly\tools.py in return_figure_from_figure_or_data(figure_or_data, validate_figure)
#     551
#     552         try:
# --> 553             figure = Figure(**figure).to_dict()
#     554         except exceptions.PlotlyError as err:
#     555             raise exceptions.PlotlyError(
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\_figure.py in __init__(self, data, layout, frames, skip_invalid, **kwargs)
#     586                         subset of frames.
#     587                     layout
# --> 588                         Layout properties which this frame modifies.
#     589                         The format is identical to the normal layout
#     590                         definition.
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
#     271
#     272         # Process kwargs
# --> 273         # --------------
#     274         for k, v in kwargs.items():
#     275             if k in self:
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _initialize_layout_template(self)
#    1815         plotly.tools.make_subplots
#    1816
# -> 1817         Parameters
#    1818         ----------
#    1819         row: int
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setattr__(self, prop, value)
#    4308                 "Subplot properties may only be suffixed by an "
#    4309                 "integer >= 1\n"
# -> 4310                 "Received {k}".format(k=prop)
#    4311             )
#    4312
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setattr__(self, prop, value)
#    3377
#    3378     def __contains__(self, prop):
# -> 3379         """
#    3380         Determine whether object contains a property or nested property
#    3381
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\__init__.py in template(self, val)
#    2866                  'magenta', 'magma', 'matter', 'mint', 'mrybm', 'mygbm', 'oranges',
#    2867                  'orrd', 'oryel', 'peach', 'phase', 'picnic', 'pinkyl', 'piyg',
# -> 2868                  'plasma', 'plotly3', 'portland', 'prgn', 'pubu', 'pubugn', 'puor',
#    2869                  'purd', 'purp', 'purples', 'purpor', 'rainbow', 'rdbu', 'rdgy',
#    2870                  'rdpu', 'rdylbu', 'rdylgn', 'redor', 'reds', 'solar', 'spectral',
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    4294         value
#    4295             Subplot value
# -> 4296         """
#    4297         # Get regular expression match
#    4298         # ----------------------------
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    3343         # ----------------
#    3344         if prop and prop[0] in self._mapped_properties:
# -> 3345             prop = self._mapped_properties[prop[0]] + prop[1:]
#    3346
#    3347         # Handle scalar case
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_compound_prop(self, prop, val)
#    3694         """
#    3695         Remove the value associated with the specified key and return it
# -> 3696
#    3697         Parameters
#    3698         ----------
#
# ~\Anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2701             # (could be any hashable object)
#    2702             if v in pio.templates:
# -> 2703                 return copy.deepcopy(pio.templates[v])
#    2704             # Otherwise, if v is a string, check to see if it consists of
#    2705             # multiple template names joined on '+' characters
#
# ~\Anaconda3\lib\site-packages\plotly\io\_templates.py in __getitem__(self, item)
#      75         for template_name in template_names:
#      76             template = self._templates[template_name]
# ---> 77             if template is Lazy:
#      78                 from plotly.graph_objs.layout import Template
#      79
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\layout\__init__.py in __init__(self, arg, data, layout, **kwargs)
#    9260         Returns
#    9261         -------
# -> 9262         Template
#    9263         """
#    9264         super(Template, self).__init__("template")
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    3343         # ----------------
#    3344         if prop and prop[0] in self._mapped_properties:
# -> 3345             prop = self._mapped_properties[prop[0]] + prop[1:]
#    3346
#    3347         # Handle scalar case
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_compound_prop(self, prop, val)
#    3694         """
#    3695         Remove the value associated with the specified key and return it
# -> 3696
#    3697         Parameters
#    3698         ----------
#
# ~\Anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2431
#    2432         elif isinstance(v, dict):
# -> 2433             v = self.data_class(v, skip_invalid=skip_invalid)
#    2434
#    2435         elif isinstance(v, self.data_class):
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\layout\template\__init__.py in __init__(self, arg, area, barpolar, bar, box, candlestick, carpet, choroplethmapbox, choropleth, cone, contourcarpet, contour, densitymapbox, funnelarea, funnel, heatmapgl, heatmap, histogram2dcontour, histogram2d, histogram, indicator, isosurface, mesh3d, ohlc, parcats, parcoords, pie, pointcloud, sankey, scatter3d, scattercarpet, scattergeo, scattergl, scattermapbox, scatterpolargl, scatterpolar, scatter, scatterternary, splom, streamtube, sunburst, surface, table, violin, volume, waterfall, **kwargs)
#    1475
#    1476         # Initialize validators
# -> 1477         # ---------------------
#    1478         self._validators["area"] = v_data.AreasValidator()
#    1479         self._validators["barpolar"] = v_data.BarpolarsValidator()
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    3347         # Handle scalar case
#    3348         # ------------------
# -> 3349         # e.g. ('foo',)
#    3350         if len(prop) == 1:
#    3351             # Unwrap scalar tuple
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _set_array_prop(self, prop, val)
#    3769         # -----------
#    3770         if val is None:
# -> 3771             # Check if we should send null update
#    3772             if self._props and prop in self._props:
#    3773                 # Remove property if not in batch mode
#
# ~\Anaconda3\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2519                     res.append(self.data_class(v_el))
#    2520                 elif isinstance(v_el, dict):
# -> 2521                     res.append(self.data_class(v_el, skip_invalid=skip_invalid))
#    2522                 else:
#    2523                     if skip_invalid:
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\__init__.py in __init__(self, arg, a, a0, aaxis, asrc, b, b0, baxis, bsrc, carpet, cheaterslope, color, customdata, customdatasrc, da, db, font, hoverinfo, hoverinfosrc, hoverlabel, ids, idssrc, meta, metasrc, name, opacity, stream, uid, uirevision, visible, x, xaxis, xsrc, y, yaxis, ysrc, **kwargs)
#   83412                 bordercolor
#   83413                     Sets the border color of the hover labels for
# > 83414                     this trace.
#   83415                 bordercolorsrc
#   83416                     Sets the source reference on plot.ly for
#
# AttributeError: module 'plotly.validators.carpet' has no attribute 'HoverinfoValidator'

# %% [markdown]
# ## histogram

# %%
df['A'].iplot(kind='hist',bins=25)

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')

# %% [markdown]
# ## scatter_matrix()
#
# Similar to sns.pairplot()

# %%
df.scatter_matrix()

# %% [markdown]
# # Great Job!
